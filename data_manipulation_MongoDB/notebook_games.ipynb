# %% [markdown]
# # Importing the necessary libraries and the dataset

# %%
import pandas as pd
import re

# %%
df =pd.read_csv('/home/lorenzo/Documents/3-TERZO-ANNO/IUMTWEB/CSV_progetto/games.csv')
df.shape
# Out:
# (65216, 23)

# %% [markdown]
# # Checking the types of the columns

# %%
df.dtypes
# Out:
# game_id                     int64
# competition_id             object
# season                      int64
# round                      object
# date                       object
# home_club_id                int64
# away_club_id                int64
# home_club_goals             int64
# away_club_goals             int64
# home_club_position        float64
# away_club_position        float64
# home_club_manager_name     object
# away_club_manager_name     object
# stadium                    object
# attendance                float64
# referee                    object
# url                        object
# home_club_formation        object
# away_club_formation        object
# home_club_name             object
# away_club_name             object
# aggregate                  object
# competition_type           object
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# # Dropping the columns that are not useful for the database

# %%
df.drop(columns=['home_club_position','away_club_position','attendance','home_club_formation','away_club_formation','url'], inplace=True)

# %% [markdown]
# # Creating a function to filter only the europian characters

# %%
def contains_only_european_chars(s):
    return re.match(r'^[a-zA-Z0-9\s\.,;:!?\-\'\"()€£\u00C0-\u017F]+$', s) is not None

# %% [markdown]
# # Dropping the rows with NaN values

# %%
df = df.dropna()

# %% [markdown]
# # Applying the function to the columns that are String type

# %%
columns_to_filter = ['home_club_manager_name', 'away_club_manager_name', 'stadium','referee','home_club_name','away_club_name']
df[columns_to_filter] =df[columns_to_filter].astype('str')
for column in columns_to_filter:
    df_filtered = df[df[column].apply(contains_only_european_chars)]

# %%
df_filtered.shape
# Out:
# (51055, 17)

# %%
df_filtered
# Out:
#        game_id competition_id  season         round       date  home_club_id  \
# 0      2222597            RU1    2012   6. Matchday 2012-08-25          3725
# 1      2222627            RU1    2012   5. Matchday 2012-08-20          2696
# 2      2222658            RU1    2012  10. Matchday 2012-09-30          2410
# 3      2222664            RU1    2012   8. Matchday 2012-09-15           932
# 4      2222683            RU1    2012  12. Matchday 2012-10-22          2696
# ...        ...            ...     ...           ...        ...           ...
# 65165  3852607            NL1    2022  12. Matchday 2022-10-30           383
# 65166  2589097            NL1    2015  23. Matchday 2016-02-14           467
# 65167  2700827            NL1    2016  23. Matchday 2017-02-18           383
# 65168  3852741            NL1    2022  27. Matchday 2023-04-01           467
# 65169  4097959            NL1    2023   5. Matchday 2023-09-16           383
#
#        away_club_id  home_club_goals  away_club_goals home_club_manager_name  \
# 0               232                2                1   Stanislav Cherchesov
# 1              4128                0                2         Andrey Kobelev
# 2               121                0                2         Leonid Slutski
# 3              2698                1                0           Slaven Bilic
# 4             12438                0                1         Andrey Kobelev
# ...             ...              ...              ...                    ...
# 65165           467                3                0    Ruud van Nistelrooy
# 65166           383                0                3           Ernest Faber
# 65167           467                3                1           Phillip Cocu
# 65168           383                2                4          Rogier Meijer
# 65169           467                4                0             Peter Bosz
#
#       away_club_manager_name          stadium                 referee  \
# 0                 Unai Emery     Akhmat-Arena    Vladislav Bezborodov
# 1              Rustem Khuzin        Metallurg           Sergey Ivanov
# 2               Dan Petrescu     Arena Khimki          Sergey Karasev
# 3             Kurban Berdyev        RZD Arena          Sergey Karasev
# 4            Gadzhi Gadzhiev        Metallurg       Timur Arslanbekov
# ...                      ...              ...                     ...
# 65165          Rogier Meijer  Philips Stadion  Martin van den Kerkhof
# 65166           Phillip Cocu   Goffertstadion              Kevin Blom
# 65167          Peter Hyballa  Philips Stadion         Jochem Kamphuis
# 65168    Ruud van Nistelrooy   Goffertstadion      Edwin van de Graaf
# 65169          Rogier Meijer  Philips Stadion              Joey Kooij
#
#                                           home_club_name  \
# 0                                      RFK Akhmat Grozny
# 1                              PFK Krylya Sovetov Samara
# 2                                        PFK CSKA Moskva
# 3                     Футбольный клуб "Локомотив" Москва
# 4                              PFK Krylya Sovetov Samara
# ...                                                  ...
# 65165  Eindhovense Voetbalvereniging Philips Sport Ve...
# 65166                      Nijmegen Eendracht Combinatie
# 65167  Eindhovense Voetbalvereniging Philips Sport Ve...
# 65168                      Nijmegen Eendracht Combinatie
# 65169  Eindhovense Voetbalvereniging Philips Sport Ve...
#
#                                           away_club_name aggregate  \
# 0                                      FK Spartak Moskva       2:1
# 1                                             Amkar Perm       0:2
# 2                                       FK Dinamo Moskva       0:2
# 3                                         FC Rubin Kazan       1:0
# 4                        Volga Nizhniy Novgorod (- 2016)       0:1
# ...                                                  ...       ...
# 65165                      Nijmegen Eendracht Combinatie       3:0
# 65166  Eindhovense Voetbalvereniging Philips Sport Ve...       0:3
# 65167                      Nijmegen Eendracht Combinatie       3:1
# 65168  Eindhovense Voetbalvereniging Philips Sport Ve...       2:4
# 65169                      Nijmegen Eendracht Combinatie       4:0
#
#       competition_type
# 0      domestic_league
# 1      domestic_league
# 2      domestic_league
# 3      domestic_league
# 4      domestic_league
# ...                ...
# 65165  domestic_league
# 65166  domestic_league
# 65167  domestic_league
# 65168  domestic_league
# 65169  domestic_league
#
# [51055 rows x 17 columns]

# %% [markdown]
# # Checking the dataset to match the clubs and the players dataset

# %%
filtered_clubs = pd.read_csv('/home/lorenzo/Documents/3-TERZO-ANNO/IUMTWEB/Manipulated_data/clubs.csv')
df_filtered_filtered = df_filtered[df_filtered['home_club_id'].isin(filtered_clubs['club_id'])]
df_filtered_filtered = df_filtered_filtered[df_filtered_filtered['away_club_id'].isin(filtered_clubs['club_id'])]
df_filtered_filtered
# Out:
#        game_id competition_id  season         round       date  home_club_id  \
# 0      2222597            RU1    2012   6. Matchday 2012-08-25          3725
# 1      2222627            RU1    2012   5. Matchday 2012-08-20          2696
# 2      2222658            RU1    2012  10. Matchday 2012-09-30          2410
# 4      2222683            RU1    2012  12. Matchday 2012-10-22          2696
# 5      2222685            RU1    2012  19. Matchday 2012-12-10          2698
# ...        ...            ...     ...           ...        ...           ...
# 65165  3852607            NL1    2022  12. Matchday 2022-10-30           383
# 65166  2589097            NL1    2015  23. Matchday 2016-02-14           467
# 65167  2700827            NL1    2016  23. Matchday 2017-02-18           383
# 65168  3852741            NL1    2022  27. Matchday 2023-04-01           467
# 65169  4097959            NL1    2023   5. Matchday 2023-09-16           383
#
#        away_club_id  home_club_goals  away_club_goals home_club_manager_name  \
# 0               232                2                1   Stanislav Cherchesov
# 1              4128                0                2         Andrey Kobelev
# 2               121                0                2         Leonid Slutski
# 4             12438                0                1         Andrey Kobelev
# 5               232                0                1         Kurban Berdyev
# ...             ...              ...              ...                    ...
# 65165           467                3                0    Ruud van Nistelrooy
# 65166           383                0                3           Ernest Faber
# 65167           467                3                1           Phillip Cocu
# 65168           383                2                4          Rogier Meijer
# 65169           467                4                0             Peter Bosz
#
#       away_club_manager_name                 stadium                 referee  \
# 0                 Unai Emery            Akhmat-Arena    Vladislav Bezborodov
# 1              Rustem Khuzin               Metallurg           Sergey Ivanov
# 2               Dan Petrescu            Arena Khimki          Sergey Karasev
# 4            Gadzhi Gadzhiev               Metallurg       Timur Arslanbekov
# 5             Valeriy Karpin  Central Stadium  Kazan    Vladislav Bezborodov
# ...                      ...                     ...                     ...
# 65165          Rogier Meijer         Philips Stadion  Martin van den Kerkhof
# 65166           Phillip Cocu          Goffertstadion              Kevin Blom
# 65167          Peter Hyballa         Philips Stadion         Jochem Kamphuis
# 65168    Ruud van Nistelrooy          Goffertstadion      Edwin van de Graaf
# 65169          Rogier Meijer         Philips Stadion              Joey Kooij
#
#                                           home_club_name  \
# 0                                      RFK Akhmat Grozny
# 1                              PFK Krylya Sovetov Samara
# 2                                        PFK CSKA Moskva
# 4                              PFK Krylya Sovetov Samara
# 5                                         FC Rubin Kazan
# ...                                                  ...
# 65165  Eindhovense Voetbalvereniging Philips Sport Ve...
# 65166                      Nijmegen Eendracht Combinatie
# 65167  Eindhovense Voetbalvereniging Philips Sport Ve...
# 65168                      Nijmegen Eendracht Combinatie
# 65169  Eindhovense Voetbalvereniging Philips Sport Ve...
#
#                                           away_club_name aggregate  \
# 0                                      FK Spartak Moskva       2:1
# 1                                             Amkar Perm       0:2
# 2                                       FK Dinamo Moskva       0:2
# 4                        Volga Nizhniy Novgorod (- 2016)       0:1
# 5                                      FK Spartak Moskva       0:1
# ...                                                  ...       ...
# 65165                      Nijmegen Eendracht Combinatie       3:0
# 65166  Eindhovense Voetbalvereniging Philips Sport Ve...       0:3
# 65167                      Nijmegen Eendracht Combinatie       3:1
# 65168  Eindhovense Voetbalvereniging Philips Sport Ve...       2:4
# 65169                      Nijmegen Eendracht Combinatie       4:0
#
#       competition_type
# 0      domestic_league
# 1      domestic_league
# 2      domestic_league
# 4      domestic_league
# 5      domestic_league
# ...                ...
# 65165  domestic_league
# 65166  domestic_league
# 65167  domestic_league
# 65168  domestic_league
# 65169  domestic_league
#
# [49615 rows x 17 columns]

# %% [markdown]
# # Saving the dataset

# %%
df_filtered_filtered.to_csv('/home/lorenzo/Documents/3-TERZO-ANNO/IUMTWEB/Manipulated_data/games.csv',index=False)
